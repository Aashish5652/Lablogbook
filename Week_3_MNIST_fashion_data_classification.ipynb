# %% [markdown]
# # MNIST Fashion Dataset Application with Keras
#
# This is a sample image classification tutorial with the MNIST fashion image dataset.

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

# Your code to import tensorflow
import tensorflow as tf
# Your code to import Keras
from tensorflow import keras
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
from tensorflow.keras.optimizers import SGD


# Your code to import numpy
import numpy as np

import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.15.0

# %% [markdown]
# ## Import the Fashion MNIST dataset
# This guide uses the Fashion MNIST dataset which contains 70,000 grayscale images in 10 categories. The images show individual articles of clothing at low resolution (28 by 28 pixels), as seen below.
#
# Here, 60,000 images are used to train the network and 10,000 images to evaluate how accurately the network learned to classify images. You can access the Fashion MNIST directly from TensorFlow. Import and load the Fashion MNIST data directly from TensorFlow:

# %%
from IPython.display import display, Image

fashion_mnist = tf.keras.datasets.fashion_mnist

myImage = Image('your_image_name');

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %% [markdown]
# Loading the dataset returns four NumPy arrays:
#
# * The `train_images` and `train_labels` arrays are the *training set*—the data the model uses to learn.
# * The model is tested against the *test set*, the `test_images`, and `test_labels` arrays.
#
# The images are 28x28 NumPy arrays, with pixel values ranging from 0 to 255. The *labels* are an array of integers, ranging from 0 to 9. These correspond to the *class* of clothing the image represents:
#
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>
#
# Each image is mapped to a single label. Since the *class names* are not included with the dataset, store them here to use later when plotting the images:

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## Explore the data
#
# Let's explore the format of the dataset before training the model. The following shows there are 60,000 images in the training set, with each image represented as 28 x 28 pixels:

# %%
# Your code to print the shape of the training images
print("Train images shape:", train_images.shape)
# Out:
# Train images shape: (60000, 28, 28)

# %% [markdown]
# Likewise, there are 60,000 labels in the training set:

# %%
# Your code to print length of train labels
# print("Train images label:", train_labels.shape)
len(train_labels)
# Out:
# 60000

# %% [markdown]
# Each label is an integer between 0 and 9:

# %%
# Your code to print the training labels
train_labels
# Out:
# array([9, 0, 0, ..., 3, 0, 5], dtype=uint8)

# %% [markdown]
# There are 10,000 images in the test set. Again, each image is represented as 28 x 28 pixels:

# %%
# Your code to print the shape of the test set images
test_images.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# And the test set contains 10,000 images labels:

# %%
# Your code to print the length of the test labels
len(test_images)
# Out:
# 10000

# %% [markdown]
# ## Preprocess the data
#
# The data must be preprocessed before training the network. If you inspect the first image in the training set, you will see that the pixel values fall in the range of 0 to 255:

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.grid(False)
plt.show()

# %% [markdown]
# Scale these values to a range of 0 to 1 before feeding them to the neural network model. To do so, divide the values by 255. It's important that the *training set* and the *testing set* be preprocessed in the same way:

# %%
train_images = train_images / 255.0

test_images = test_images / 255.0

# %% [markdown]
# To verify that the data is in the correct format and that you're ready to build and train the network, let's display the first 25 images from the *training set* and display the class name below each image.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[train_labels[i]])
plt.show()

# %% [markdown]
# ## Build the model
#
# Building the neural network requires configuring the layers of the model, then compiling the model.

# %% [markdown]
# Develop a a neural network model of your choice i.e. number of layers and activation function. Remember the input is a 2-D so you need to flatten the input.

# %%
#
# Your code to build the neural network model.
model = Sequential()
# Use model.add.Flatten() layer as the first layer.
model.add(Flatten(input_shape=(28, 28)))
# Chose softmax in the output layer. Chose the number of layers and actication functions in hidden layers of your choice.

model.add(Dense(270, activation='relu'))
# Do not forget to set correct number of neurons in the output layer.
model.add(Dense(10, activation='softmax'))
#

# %%
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 270)               211950
#
#  dense_3 (Dense)             (None, 10)                2710
#
# =================================================================
# Total params: 214660 (838.52 KB)
# Trainable params: 214660 (838.52 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# ### Compile the model
#
# Before the model is ready for training, it needs a few more settings. These are added during the model's *compile* step:
#
# * *Loss function* —This measures how accurate the model is during training. You want to minimize this function to "steer" the model in the right direction.
# * *Optimizer* —This is how the model is updated based on the data it sees and its loss function.
# * *Metrics* —Used to monitor the training and testing steps. The following example uses *accuracy*, the fraction of the images that are correctly classified.
#
#
# We have used 'adam' optimizer. Try other optimizer functions. Use Keras API as a reference

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Train the model
#
# Training the neural network model requires the following steps:
#
# 1. Feed the training data to the model. In this example, the training data is in the `train_images` and `train_labels` arrays.
# 2. The model learns to associate images and labels.
# 3. You ask the model to make predictions about a test set—in this example, the `test_images` array.
# 4. Verify that the predictions match the labels from the `test_labels` array.

# %% [markdown]
# ### Feed the model
#
# To start training,  call the `model.fit` method—so called because it "fits" the model to the training data:

# %%
model.fit(train_images, train_labels, epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 11s 5ms/step - loss: 0.4859 - accuracy: 0.8281
# Epoch 2/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.3631 - accuracy: 0.8690
# Epoch 3/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.3280 - accuracy: 0.8794
# Epoch 4/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.2991 - accuracy: 0.8891
# Epoch 5/100
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2813 - accuracy: 0.8946
# Epoch 6/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2689 - accuracy: 0.8983
# Epoch 7/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2567 - accuracy: 0.9030
# Epoch 8/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2445 - accuracy: 0.9089
# Epoch 9/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2353 - accuracy: 0.9126
# Epoch 10/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2274 - accuracy: 0.9141
# Epoch 11/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2169 - accuracy: 0.9179
# Epoch 12/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2102 - accuracy: 0.9210
# Epoch 13/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.2002 - accuracy: 0.9240
# Epoch 14/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1957 - accuracy: 0.9261
# Epoch 15/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1884 - accuracy: 0.9294
# Epoch 16/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1841 - accuracy: 0.9315
# Epoch 17/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1781 - accuracy: 0.9323
# Epoch 18/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1709 - accuracy: 0.9352
# Epoch 19/100
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1673 - accuracy: 0.9372
# Epoch 20/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1621 - accuracy: 0.9379
# Epoch 21/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1594 - accuracy: 0.9397
# Epoch 22/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1541 - accuracy: 0.9427
# Epoch 23/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1483 - accuracy: 0.9435
# Epoch 24/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1482 - accuracy: 0.9438
# Epoch 25/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1398 - accuracy: 0.9468
# Epoch 26/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1403 - accuracy: 0.9470
# Epoch 27/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1349 - accuracy: 0.9493
# Epoch 28/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1309 - accuracy: 0.9501
# Epoch 29/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1277 - accuracy: 0.9522
# Epoch 30/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1269 - accuracy: 0.9529
# Epoch 31/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1224 - accuracy: 0.9536
# Epoch 32/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1211 - accuracy: 0.9551
# Epoch 33/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1173 - accuracy: 0.9551
# Epoch 34/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1150 - accuracy: 0.9566
# Epoch 35/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1139 - accuracy: 0.9565
# Epoch 36/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.1099 - accuracy: 0.9578
# Epoch 37/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.1072 - accuracy: 0.9600
# Epoch 38/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1053 - accuracy: 0.9605
# Epoch 39/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.1032 - accuracy: 0.9609
# Epoch 40/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1032 - accuracy: 0.9612
# Epoch 41/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0983 - accuracy: 0.9624
# Epoch 42/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0961 - accuracy: 0.9636
# Epoch 43/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0960 - accuracy: 0.9636
# Epoch 44/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0920 - accuracy: 0.9651
# Epoch 45/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0905 - accuracy: 0.9657
# Epoch 46/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0911 - accuracy: 0.9661
# Epoch 47/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0876 - accuracy: 0.9674
# Epoch 48/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0877 - accuracy: 0.9666
# Epoch 49/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0860 - accuracy: 0.9677
# Epoch 50/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0843 - accuracy: 0.9677
# Epoch 51/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0817 - accuracy: 0.9689
# Epoch 52/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0826 - accuracy: 0.9690
# Epoch 53/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0808 - accuracy: 0.9697
# Epoch 54/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0754 - accuracy: 0.9719
# Epoch 55/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0775 - accuracy: 0.9711
# Epoch 56/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0772 - accuracy: 0.9702
# Epoch 57/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0736 - accuracy: 0.9725
# Epoch 58/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0728 - accuracy: 0.9726
# Epoch 59/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0728 - accuracy: 0.9722
# Epoch 60/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0695 - accuracy: 0.9742
# Epoch 61/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0745 - accuracy: 0.9722
# Epoch 62/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0691 - accuracy: 0.9735
# Epoch 63/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0677 - accuracy: 0.9747
# Epoch 64/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0667 - accuracy: 0.9751
# Epoch 65/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0651 - accuracy: 0.9754
# Epoch 66/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0688 - accuracy: 0.9750
# Epoch 67/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0660 - accuracy: 0.9752
# Epoch 68/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0610 - accuracy: 0.9769
# Epoch 69/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0611 - accuracy: 0.9775
# Epoch 70/100
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0625 - accuracy: 0.9773
# Epoch 71/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0609 - accuracy: 0.9772
# Epoch 72/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0643 - accuracy: 0.9759
# Epoch 73/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0614 - accuracy: 0.9773
# Epoch 74/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0560 - accuracy: 0.9787
# Epoch 75/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0574 - accuracy: 0.9786
# Epoch 76/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0565 - accuracy: 0.9791
# Epoch 77/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0577 - accuracy: 0.9780
# Epoch 78/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0571 - accuracy: 0.9790
# Epoch 79/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0537 - accuracy: 0.9805
# Epoch 80/100
# 1875/1875 [==============================] - 8s 5ms/step - loss: 0.0532 - accuracy: 0.9801
# Epoch 81/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0525 - accuracy: 0.9806
# Epoch 82/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0543 - accuracy: 0.9797
# Epoch 83/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0508 - accuracy: 0.9811
# Epoch 84/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0536 - accuracy: 0.9802
# Epoch 85/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0511 - accuracy: 0.9805
# Epoch 86/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0533 - accuracy: 0.9798
# Epoch 87/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0496 - accuracy: 0.9815
# Epoch 88/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0489 - accuracy: 0.9821
# Epoch 89/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0492 - accuracy: 0.9820
# Epoch 90/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0495 - accuracy: 0.9819
# Epoch 91/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0481 - accuracy: 0.9820
# Epoch 92/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0491 - accuracy: 0.9814
# Epoch 93/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0494 - accuracy: 0.9819
# Epoch 94/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0450 - accuracy: 0.9836
# Epoch 95/100
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0451 - accuracy: 0.9835
# Epoch 96/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0480 - accuracy: 0.9828
# Epoch 97/100
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0458 - accuracy: 0.9835
# Epoch 98/100
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0425 - accuracy: 0.9847
# Epoch 99/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0469 - accuracy: 0.9832
# Epoch 100/100
# 1875/1875 [==============================] - 9s 5ms/step - loss: 0.0438 - accuracy: 0.9836

# %% [markdown]
# As the model trains, the loss and accuracy metrics are displayed. This model reaches an accuracy of about 0.91 (or 91%) on the training data.

# %% [markdown]
# ### Evaluate accuracy
#
# Next, compare how the model performs on the test dataset:

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)

print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 1s - loss: 0.8132 - accuracy: 0.8947 - 938ms/epoch - 3ms/step
#
# Test accuracy: 0.8946999907493591

# %% [markdown]
# ### Make predictions
#
# With the model trained, you can use it to make predictions about some images.

# %%
predictions = model.predict(test_images)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %% [markdown]
# Here, the model has predicted the label for each image in the testing set. Let's take a look at the first prediction:

# %%
predictions[0]
# Out:
# array([3.0991020e-28, 2.0006623e-29, 7.8077065e-22, 0.0000000e+00,
#        1.7541929e-36, 1.8346962e-14, 2.2510704e-29, 1.7181845e-10,
#        2.2928836e-32, 1.0000000e+00], dtype=float32)

# %% [markdown]
# A prediction is an array of 10 numbers. They represent the model's "confidence" that the image corresponds to each of the 10 different articles of clothing. You can see which label has the highest confidence value:

# %%
np.argmax(predictions[0])
# Out:
# 9

# %% [markdown]
# So, the model is most confident that this image is an ankle boot, or `class_names[9]`. Examining the test label shows that this classification is correct:

# %%
test_labels[0]
# Out:
# 9

# %% [markdown]
# Graph this to look at the full set of 10 class predictions.

# %%
def plot_image(i, predictions_array, true_label, img):
  predictions_array, true_label, img = predictions_array, true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  predictions_array, true_label = predictions_array, true_label[i]
  plt.grid(False)
  plt.xticks(range(10))
  plt.yticks([])
  thisplot = plt.bar(range(10), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %% [markdown]
# ### Verify predictions
#
# With the model trained, you can use it to make predictions about some images.

# %% [markdown]
# Let's look at the 0th image, predictions, and prediction array. Correct prediction labels are blue and incorrect prediction labels are red. The number gives the percentage (out of 100) for the predicted label.

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %% [markdown]
# Plot any other image

# %%
# Your code to plot any other image and confidense score of your choise
i = 100
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions[i], test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions[i],  test_labels)
plt.show()

# %% [markdown]
# Let's plot several images with their predictions.
# In the next cell, you need to plot first 15 images in the following format.
#
# Use the sample code of the plots provided in this tutorial. Hint - You need to
# use subplots, for loop, etc..
#
# ![image.png](data:image/png;base64,...)

# %%
#
# Your code to plot first 15 predictions in the above format.
#i=0
plt.figure(figsize=(6,3))
for i in range(15):
  
    plt.subplot(3 , 5, i + 1)  # 3 rows, 5 columns, index i+1
    plot_image(i, predictions[i], test_labels, test_images)
    plt.subplot(3, 5 , i + 1)
    plot_value_array(i, predictions[i], test_labels)

plt.show()

#

# %% [markdown]
# ## Use the trained model
#
# Finally, use the trained model to make a prediction about a single image.

# %%
img = test_images[1]

# Your code to print the shape of the image
img.shape
# Out:
# (28, 28)

# %% [markdown]
# `tf.keras` models are optimized to make predictions on a *batch*, or collection, of examples at once. Accordingly, even though you're using a single image, you need to add it to a list:

# %%
img = (np.expand_dims(img,0))

# Your code to print the shape of the image.
img.shape
# Out:
# (1, 28, 28)

# %% [markdown]
# Now predict the correct label for this image:

# %%
predictions_single = model.predict(img)

print(predictions_single)
# Out:
# 1/1 [==============================] - 0s 38ms/step
# [[3.2035105e-06 3.2376873e-32 9.9999428e-01 2.6712547e-33 2.5098313e-06
#   3.3062549e-34 1.4075149e-11 2.0895355e-35 4.9291633e-34 0.0000000e+00]]

# %%
plot_value_array(1, predictions_single[0], test_labels)
_ = plt.xticks(range(10), class_names, rotation=45)

# %% [markdown]
# `model.predict` returns a list of lists—one list for each image in the batch of data. Grab the predictions for our (only) image in the batch:

# %%
np.argmax(predictions_single[0])
# Out:
# 2

# %% [markdown]
# # **Lab Logbook Requirement:**
#
# # Please record the model's accuracy and a summary of its development. You can obtain the model summary using the model.summary() method. The API for obtaining the model summary is defined in the following link:
#
# # https://keras.io/api/models/model/#summary-method
#
# # Ensure that no code or other information is added to the logbook and that only required information is present.  Marks will not be awarded if anything else is found in the logbook or instructions are not clearly followed.
